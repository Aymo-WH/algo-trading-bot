# %% [markdown]
# <a href="https://colab.research.google.com/github/Aymo-WH/algo-trading-bot/blob/main/TheAlgoTradingBot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Project Setup

# %% [markdown]
# ## Phase 1 & 2: Environment Setup and Data Factory
# Description: This cell connects the Colab engine to our GitHub repository, installs the required quantitative finance libraries, and runs the Data Factory to generate our multi-stock datasets.

# %%
# 1. Install the necessary trading and AI libraries
# !pip install gymnasium stable-baselines3[extra] yfinance pandas_ta -q

# 2. Clone the central repository from GitHub
# !git clone https://github.com/Aymo-WH/algo-trading-bot.git

# 3. Enter the repository folder
# %cd /content/algo-trading-bot
! git pull

# 4. Create the data folder if it doesn't exist
# !mkdir -p data

# 5. Run the Data Factory to download the stock data into the /data folder
print("Firing up the Data Factory...")
# !python data_factory.py
# Out:
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.12/dist-packages)
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.12/dist-packages)
#     WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.12/dist-packages)
#     WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.12/dist-packages)
#     WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.12/dist-packages)
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.12/dist-packages)
# ERROR: Operation cancelled by user
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/base_command.py", line 179, in exc_logging_wrapper
#     status = run_func(*args)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/req_command.py", line 67, in wrapper
#     return func(self, options, args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/commands/install.py", line 480, in run
#     installed_dist = env.get_distribution(item)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/metadata/importlib/_envs.py", line 189, in get_distribution
#     return next(matches, None)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/metadata/importlib/_envs.py", line 186, in <genexpr>
#     for distribution in self.iter_all_distributions()
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/metadata/base.py", line 612, in iter_all_distributions
#     for dist in self._iter_distributions():
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/metadata/importlib/_envs.py", line 176, in _iter_distributions
#     yield from finder.find(location)
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/metadata/importlib/_envs.py", line 79, in find
#     for dist, info_location in self._find_impl(location):
#                                ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/metadata/importlib/_envs.py", line 64, in _find_impl
#     raw_name = get_dist_name(dist)
#                ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/metadata/importlib/_compat.py", line 52, in get_dist_name
#     name = cast(Any, dist).name
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/importlib/metadata/__init__.py", line 457, in name
#     return self.metadata['Name']
#            ^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/importlib/metadata/__init__.py", line 452, in metadata
#     return _adapters.Message(email.message_from_string(text))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/importlib/metadata/_adapters.py", line 47, in __init__
#     self._headers = self._repair_headers()
#                     ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/importlib/metadata/_adapters.py", line 70, in _repair_headers
#     headers = [(key, redent(value)) for key, value in vars(self)['_headers']]
#                      ^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/importlib/metadata/_adapters.py", line 68, in redent
#     return textwrap.dedent(' ' * 8 + value)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/textwrap.py", line 436, in dedent
#     indents = _leading_whitespace_re.findall(text)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/bin/pip3", line 10, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/main.py", line 80, in main
#     return command.main(cmd_args)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/base_command.py", line 100, in main
#     return self._main(args)
#            ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/base_command.py", line 232, in _main
#     return run(options, args)
#            ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/base_command.py", line 216, in exc_logging_wrapper
#     logger.debug("Exception information:", exc_info=True)
#   File "/usr/lib/python3.12/logging/__init__.py", line 1527, in debug
#     self._log(DEBUG, msg, args, **kwargs)
#   File "/usr/lib/python3.12/logging/__init__.py", line 1684, in _log
#     self.handle(record)
#   File "/usr/lib/python3.12/logging/__init__.py", line 1700, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.12/logging/__init__.py", line 1762, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.12/logging/__init__.py", line 1028, in handle
#     self.emit(record)
#   File "/usr/lib/python3.12/logging/handlers.py", line 75, in emit
#     logging.FileHandler.emit(self, record)
#   File "/usr/lib/python3.12/logging/__init__.py", line 1280, in emit
#     StreamHandler.emit(self, record)
#   File "/usr/lib/python3.12/logging/__init__.py", line 1160, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/logging/__init__.py", line 999, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/utils/logging.py", line 112, in format
#     formatted = super().format(record)
#                 ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/logging/__init__.py", line 711, in format
#     record.exc_text = self.formatException(record.exc_info)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/logging/__init__.py", line 661, in formatException
#     traceback.print_exception(ei[0], ei[1], tb, None, sio)
#   File "/usr/lib/python3.12/traceback.py", line 124, in print_exception
#     te = TracebackException(type(value), value, tb, limit=limit, compact=True)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/traceback.py", line 733, in __init__
#     self.stack = StackSummary._extract_from_extended_frame_gen(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/traceback.py", line 438, in _extract_from_extended_frame_gen
#     f.line
#   File "/usr/lib/python3.12/traceback.py", line 323, in line
#     self._line = linecache.getline(self.filename, self.lineno)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/linecache.py", line 30, in getline
#     lines = getlines(filename, module_globals)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/linecache.py", line 46, in getlines
#     return updatecache(filename, module_globals)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/linecache.py", line 141, in updatecache
#     with tokenize.open(fullname) as fp:
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/tokenize.py", line 459, in open
#     encoding, lines = detect_encoding(buffer.readline)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/tokenize.py", line 428, in detect_encoding
#     first = read_or_stop()
#             ^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/tokenize.py", line 386, in read_or_stop
#     return readline()
#            ^^^^^^^^^^
# KeyboardInterrupt
# ^C
# fatal: destination path 'algo-trading-bot' already exists and is not an empty directory.
# /content/algo-trading-bot
# Already up to date.
# Firing up the Data Factory...
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# Fetching NVDA data from 2020-01-01 to 2026-02-21...
# /content/algo-trading-bot/data_factory.py:57: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start_date, end=end_date)
# /usr/local/lib/python3.12/dist-packages/yfinance/scrapers/history.py:204: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [*********************100%***********************]  1 of 1 completed
# Calculating RSI for NVDA...
# Calculating MACD for NVDA...
# Calculating Simulated Sentiment for NVDA...
# Data saved to data/NVDA_data.csv
# Fetching AAPL data from 2020-01-01 to 2026-02-21...
# /content/algo-trading-bot/data_factory.py:57: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start_date, end=end_date)
# /usr/local/lib/python3.12/dist-packages/yfinance/scrapers/history.py:204: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [*********************100%***********************]  1 of 1 completed
# Calculating RSI for AAPL...
# Calculating MACD for AAPL...
# Calculating Simulated Sentiment for AAPL...
# Data saved to data/AAPL_data.csv
# Fetching MSFT data from 2020-01-01 to 2026-02-21...
# /content/algo-trading-bot/data_factory.py:57: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start_date, end=end_date)
# /usr/local/lib/python3.12/dist-packages/yfinance/scrapers/history.py:204: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [*********************100%***********************]  1 of 1 completed
# Calculating RSI for MSFT...
# Calculating MACD for MSFT...
# Calculating Simulated Sentiment for MSFT...
# Data saved to data/MSFT_data.csv
# Fetching AMD data from 2020-01-01 to 2026-02-21...
# /content/algo-trading-bot/data_factory.py:57: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start_date, end=end_date)
# /usr/local/lib/python3.12/dist-packages/yfinance/scrapers/history.py:204: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [*********************100%***********************]  1 of 1 completed
# Calculating RSI for AMD...
# Calculating MACD for AMD...
# Calculating Simulated Sentiment for AMD...
# Data saved to data/AMD_data.csv
# Fetching INTC data from 2020-01-01 to 2026-02-21...
# /content/algo-trading-bot/data_factory.py:57: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start_date, end=end_date)
# /usr/local/lib/python3.12/dist-packages/yfinance/scrapers/history.py:204: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [*********************100%***********************]  1 of 1 completed
# Calculating RSI for INTC...
# Calculating MACD for INTC...
# Calculating Simulated Sentiment for INTC...
# Data saved to data/INTC_data.csv

# %%
# %cd /content/algo-trading-bot
# !git pull
# Out:
# /content/algo-trading-bot
# Already up to date.

# %% [markdown]
# # AI Training (Phase 3)

# %% [markdown]
# ## Phase 3: Training the Gladiator Agents
# Description: Here we train both the PPO (Safe/Steady) and DQN (Value Hunter) algorithms for 50,000 timesteps. Because of our refactored codebase, these scripts will automatically save the brains into the `models/` folder.

# %%
# Train the PPO Agent
print("--- Training PPO Agent (50,000 Steps) ---")
# !python train_agent.py

# Train the DQN Agent
print("\n--- Training DQN Agent (50,000 Steps) ---")
# !python train_agent_dqn.py
# Out:
# --- Training PPO Agent (50,000 Steps) ---
# 2026-02-24 05:37:44.263406: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-02-24 05:37:44.269989: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-02-24 05:37:44.290237: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771911464.327281     628 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771911464.338632     628 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1771911464.366790     628 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771911464.366838     628 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771911464.366845     628 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771911464.366852     628 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-02-24 05:37:44.375162: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 90       |
# |    ep_rew_mean     | -0.302   |
# | time/              |          |
# |    fps             | 1248     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 152         |
# | time/                   |             |
# |    fps                  | 957         |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.002963078 |
# |    clip_fraction        | 0.011       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.000126    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.85e+04    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.000911   |
# |    std                  | 0.995       |
# |    value_loss           | 2.32e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 311         |
# | time/                   |             |
# |    fps                  | 893         |
# |    iterations           | 3           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.002300894 |
# |    clip_fraction        | 0.00796     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | -5.13e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.51e+04    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00142    |
# |    std                  | 0.984       |
# |    value_loss           | 2.14e+05    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 90            |
# |    ep_rew_mean          | 340           |
# | time/                   |               |
# |    fps                  | 869           |
# |    iterations           | 4             |
# |    time_elapsed         | 9             |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 0.00052606344 |
# |    clip_fraction        | 4.88e-05      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.4          |
# |    explained_variance   | 0.000715      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 9.8e+04       |
# |    n_updates            | 30            |
# |    policy_gradient_loss | -0.000187     |
# |    std                  | 0.98          |
# |    value_loss           | 2.74e+05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 312          |
# | time/                   |              |
# |    fps                  | 807          |
# |    iterations           | 5            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0017854855 |
# |    clip_fraction        | 0.00264      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.00157      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.39e+04     |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00109     |
# |    std                  | 0.966        |
# |    value_loss           | 2.23e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 314         |
# | time/                   |             |
# |    fps                  | 788         |
# |    iterations           | 6           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.003775189 |
# |    clip_fraction        | 0.0101      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | -0.00105    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.14e+05    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00166    |
# |    std                  | 0.962       |
# |    value_loss           | 3.36e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 346          |
# | time/                   |              |
# |    fps                  | 791          |
# |    iterations           | 7            |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0021802962 |
# |    clip_fraction        | 0.0126       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 5.78e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.35e+04     |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00324     |
# |    std                  | 0.935        |
# |    value_loss           | 2.04e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 470          |
# | time/                   |              |
# |    fps                  | 794          |
# |    iterations           | 8            |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0031668043 |
# |    clip_fraction        | 0.0269       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | -0.00017     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.95e+04     |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00301     |
# |    std                  | 0.937        |
# |    value_loss           | 1.76e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 592          |
# | time/                   |              |
# |    fps                  | 792          |
# |    iterations           | 9            |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0033627541 |
# |    clip_fraction        | 0.0159       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.0019       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.73e+05     |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00172     |
# |    std                  | 0.936        |
# |    value_loss           | 3.44e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 746         |
# | time/                   |             |
# |    fps                  | 772         |
# |    iterations           | 10          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.005158468 |
# |    clip_fraction        | 0.0221      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | -0.002      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.14e+05    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00184    |
# |    std                  | 0.934       |
# |    value_loss           | 3.61e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 689          |
# | time/                   |              |
# |    fps                  | 775          |
# |    iterations           | 11           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0007375034 |
# |    clip_fraction        | 0.000391     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | -0.000177    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.04e+05     |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.000806    |
# |    std                  | 0.928        |
# |    value_loss           | 2.86e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 90            |
# |    ep_rew_mean          | 503           |
# | time/                   |               |
# |    fps                  | 779           |
# |    iterations           | 12            |
# |    time_elapsed         | 31            |
# |    total_timesteps      | 24576         |
# | train/                  |               |
# |    approx_kl            | 0.00071551034 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.34         |
# |    explained_variance   | -0.000653     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.15e+05      |
# |    n_updates            | 110           |
# |    policy_gradient_loss | -0.000551     |
# |    std                  | 0.926         |
# |    value_loss           | 4.17e+05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 388          |
# | time/                   |              |
# |    fps                  | 782          |
# |    iterations           | 13           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 5.455941e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.000619     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.53e+05     |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.000206    |
# |    std                  | 0.926        |
# |    value_loss           | 2.53e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 90            |
# |    ep_rew_mean          | 469           |
# | time/                   |               |
# |    fps                  | 782           |
# |    iterations           | 14            |
# |    time_elapsed         | 36            |
# |    total_timesteps      | 28672         |
# | train/                  |               |
# |    approx_kl            | 0.00054979994 |
# |    clip_fraction        | 0.000146      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.34         |
# |    explained_variance   | -0.00393      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 9.2e+04       |
# |    n_updates            | 130           |
# |    policy_gradient_loss | -0.00045      |
# |    std                  | 0.927         |
# |    value_loss           | 2.83e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 90            |
# |    ep_rew_mean          | 442           |
# | time/                   |               |
# |    fps                  | 771           |
# |    iterations           | 15            |
# |    time_elapsed         | 39            |
# |    total_timesteps      | 30720         |
# | train/                  |               |
# |    approx_kl            | 0.00055940234 |
# |    clip_fraction        | 0.000293      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.34         |
# |    explained_variance   | 0.00169       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.63e+05      |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -0.000708     |
# |    std                  | 0.922         |
# |    value_loss           | 3.62e+05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 611          |
# | time/                   |              |
# |    fps                  | 773          |
# |    iterations           | 16           |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0040334784 |
# |    clip_fraction        | 0.0209       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | -0.000702    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.46e+05     |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00169     |
# |    std                  | 0.907        |
# |    value_loss           | 3.11e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 696          |
# | time/                   |              |
# |    fps                  | 775          |
# |    iterations           | 17           |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0022902964 |
# |    clip_fraction        | 0.0248       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.000492     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.22e+05     |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00269     |
# |    std                  | 0.899        |
# |    value_loss           | 3.42e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 421          |
# | time/                   |              |
# |    fps                  | 774          |
# |    iterations           | 18           |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0035995764 |
# |    clip_fraction        | 0.0161       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.00127      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.16e+05     |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00169     |
# |    std                  | 0.895        |
# |    value_loss           | 2.23e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 397         |
# | time/                   |             |
# |    fps                  | 769         |
# |    iterations           | 19          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.005378452 |
# |    clip_fraction        | 0.0385      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | -0.000212   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.39e+04    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00387    |
# |    std                  | 0.891       |
# |    value_loss           | 2.33e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 431         |
# | time/                   |             |
# |    fps                  | 766         |
# |    iterations           | 20          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.002784621 |
# |    clip_fraction        | 0.00361     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | -0.00071    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.18e+05    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00143    |
# |    std                  | 0.89        |
# |    value_loss           | 2.38e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 412         |
# | time/                   |             |
# |    fps                  | 769         |
# |    iterations           | 21          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.003033748 |
# |    clip_fraction        | 0.00688     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.00527     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.48e+05    |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00276    |
# |    std                  | 0.888       |
# |    value_loss           | 3.58e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 642          |
# | time/                   |              |
# |    fps                  | 771          |
# |    iterations           | 22           |
# |    time_elapsed         | 58           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0009793104 |
# |    clip_fraction        | 0.000146     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.00112      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.69e+05     |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00077     |
# |    std                  | 0.888        |
# |    value_loss           | 3.19e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 820          |
# | time/                   |              |
# |    fps                  | 773          |
# |    iterations           | 23           |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0005019887 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.00253      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.98e+05     |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00065     |
# |    std                  | 0.887        |
# |    value_loss           | 3.45e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 655          |
# | time/                   |              |
# |    fps                  | 767          |
# |    iterations           | 24           |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0010376851 |
# |    clip_fraction        | 0.000293     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.00643      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.2e+05      |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.000726    |
# |    std                  | 0.889        |
# |    value_loss           | 6.59e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 631          |
# | time/                   |              |
# |    fps                  | 769          |
# |    iterations           | 25           |
# |    time_elapsed         | 66           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0010009652 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.0162       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.05e+05     |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.000512    |
# |    std                  | 0.889        |
# |    value_loss           | 2.26e+05     |
# ------------------------------------------
#
# --- Training DQN Agent (50,000 Steps) ---
# 2026-02-24 05:39:10.037552: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-02-24 05:39:10.042367: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-02-24 05:39:10.056334: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771911550.079377    1019 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771911550.088921    1019 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1771911550.106637    1019 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771911550.106703    1019 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771911550.106708    1019 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771911550.106713    1019 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-02-24 05:39:10.111831: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | -66.5    |
# |    exploration_rate | 0.932    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1587     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 360      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 95.7     |
# |    n_updates        | 64       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | -283     |
# |    exploration_rate | 0.863    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1383     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 720      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 126      |
# |    n_updates        | 154      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | -500     |
# |    exploration_rate | 0.795    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 1355     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1080     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 103      |
# |    n_updates        | 244      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | -249     |
# |    exploration_rate | 0.726    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 1315     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1440     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 96.2     |
# |    n_updates        | 334      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | -322     |
# |    exploration_rate | 0.658    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 1301     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1800     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 69.1     |
# |    n_updates        | 424      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | -235     |
# |    exploration_rate | 0.59     |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 1290     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2160     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 101      |
# |    n_updates        | 514      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | -222     |
# |    exploration_rate | 0.521    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 1277     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2520     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 75.5     |
# |    n_updates        | 604      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | -271     |
# |    exploration_rate | 0.453    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 1254     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2880     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 86.7     |
# |    n_updates        | 694      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | -273     |
# |    exploration_rate | 0.384    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 1237     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3240     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 105      |
# |    n_updates        | 784      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | -236     |
# |    exploration_rate | 0.316    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 1225     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3600     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 104      |
# |    n_updates        | 874      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | -202     |
# |    exploration_rate | 0.248    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 1206     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3960     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 84.9     |
# |    n_updates        | 964      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | -104     |
# |    exploration_rate | 0.179    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 1191     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4320     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 130      |
# |    n_updates        | 1054     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | -68.8    |
# |    exploration_rate | 0.111    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 1179     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4680     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 103      |
# |    n_updates        | 1144     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | -77.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 1166     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 5040     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 134      |
# |    n_updates        | 1234     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | -26.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 1154     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 5400     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 74       |
# |    n_updates        | 1324     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | -70.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 1146     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 5760     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 79.7     |
# |    n_updates        | 1414     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | 64.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 1124     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 6120     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 90.8     |
# |    n_updates        | 1504     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | 178      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 1092     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 6480     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 48.7     |
# |    n_updates        | 1594     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | 278      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 1065     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 6840     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 99.3     |
# |    n_updates        | 1684     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | 247      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 1046     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 7200     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 50.4     |
# |    n_updates        | 1774     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | 247      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 1025     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 7560     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 105      |
# |    n_updates        | 1864     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | 252      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 1002     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 7920     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 74.5     |
# |    n_updates        | 1954     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | 256      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 1003     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 8280     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 71.4     |
# |    n_updates        | 2044     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | 284      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 1003     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 8640     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 109      |
# |    n_updates        | 2134     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | 399      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 1006     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 9000     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 79.2     |
# |    n_updates        | 2224     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | 439      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 1008     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 9360     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 54.5     |
# |    n_updates        | 2314     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | 531      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 1008     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 9720     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 169      |
# |    n_updates        | 2404     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | 584      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 1009     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 10080    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 79.2     |
# |    n_updates        | 2494     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | 562      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 1011     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 10440    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 105      |
# |    n_updates        | 2584     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | 603      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 1011     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 10800    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 121      |
# |    n_updates        | 2674     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | 681      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 1013     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 11160    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 78       |
# |    n_updates        | 2764     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | 778      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 1013     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 11520    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 90.7     |
# |    n_updates        | 2854     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | 884      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 1013     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 11880    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 62.9     |
# |    n_updates        | 2944     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | 958      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 1014     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 12240    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 177      |
# |    n_updates        | 3034     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | 1.03e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 1016     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 12600    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 85.6     |
# |    n_updates        | 3124     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | 979      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 1016     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 12960    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 91       |
# |    n_updates        | 3214     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | 970      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 1017     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 13320    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 119      |
# |    n_updates        | 3304     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | 1.06e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 1018     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 13680    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 153      |
# |    n_updates        | 3394     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | 1.17e+03 |
# ...
# |    time_elapsed     | 39       |
# |    total_timesteps  | 38880    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 165      |
# |    n_updates        | 9694     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | 1.2e+03  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 977      |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 39240    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 236      |
# |    n_updates        | 9784     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | 1.34e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 977      |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 39600    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 157      |
# |    n_updates        | 9874     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | 1.24e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 977      |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 39960    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 171      |
# |    n_updates        | 9964     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | 1.26e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 977      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 40320    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 179      |
# |    n_updates        | 10054    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | 1.25e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 976      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 40680    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 154      |
# |    n_updates        | 10144    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | 1.17e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 976      |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 41040    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 144      |
# |    n_updates        | 10234    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | 1.21e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 974      |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 41400    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 181      |
# |    n_updates        | 10324    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | 1.31e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 975      |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 41760    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 242      |
# |    n_updates        | 10414    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | 1.32e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 975      |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 42120    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 127      |
# |    n_updates        | 10504    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | 1.35e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 972      |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 42480    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 180      |
# |    n_updates        | 10594    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | 1.52e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 969      |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 42840    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 195      |
# |    n_updates        | 10684    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | 1.61e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 967      |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 43200    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 152      |
# |    n_updates        | 10774    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | 1.58e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 963      |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 43560    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 191      |
# |    n_updates        | 10864    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | 1.53e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 959      |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 43920    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 153      |
# |    n_updates        | 10954    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | 1.53e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 959      |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 44280    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 236      |
# |    n_updates        | 11044    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | 1.43e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 960      |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 44640    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 149      |
# |    n_updates        | 11134    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | 1.34e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 960      |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 45000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 160      |
# |    n_updates        | 11224    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | 1.36e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 504      |
# |    fps              | 960      |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 45360    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 282      |
# |    n_updates        | 11314    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | 1.37e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 508      |
# |    fps              | 960      |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 45720    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 237      |
# |    n_updates        | 11404    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | 1.51e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 512      |
# |    fps              | 960      |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 46080    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 140      |
# |    n_updates        | 11494    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | 1.43e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 516      |
# |    fps              | 961      |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 46440    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 169      |
# |    n_updates        | 11584    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | 1.41e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 520      |
# |    fps              | 960      |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 46800    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 196      |
# |    n_updates        | 11674    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | 1.58e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 524      |
# |    fps              | 960      |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 47160    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 349      |
# |    n_updates        | 11764    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | 1.37e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 528      |
# |    fps              | 960      |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 47520    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 231      |
# |    n_updates        | 11854    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | 1.39e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 532      |
# |    fps              | 960      |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 47880    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 142      |
# |    n_updates        | 11944    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | 1.27e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 536      |
# |    fps              | 961      |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 48240    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 206      |
# |    n_updates        | 12034    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | 1.23e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 540      |
# |    fps              | 961      |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 48600    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 203      |
# |    n_updates        | 12124    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | 1.27e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 544      |
# |    fps              | 960      |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 48960    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 185      |
# |    n_updates        | 12214    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | 1.29e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 548      |
# |    fps              | 961      |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 49320    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 207      |
# |    n_updates        | 12304    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | 1.35e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 552      |
# |    fps              | 961      |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 49680    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 271      |
# |    n_updates        | 12394    |
# ----------------------------------

# %% [markdown]
# # The Professional Benchmark (Phase 4)

# %% [markdown]
# ## Phase 4: Professional Backtesting & ROI Calculation
# Description: This script loads both the PPO and DQN models simultaneously. To ensure a fair A/B test, it forcefully locks the environment to a single "test track" (Nvidia) so we can see how both generalized brains perform against each other and the S&P 500 on the exact same timeline.

# %%
# !python evaluate_agents.py
# Out:
# 2026-02-24 05:40:16.071044: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-02-24 05:40:16.077344: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-02-24 05:40:16.098559: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771911616.137112    1288 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771911616.148564    1288 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1771911616.176900    1288 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771911616.176961    1288 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771911616.176970    1288 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771911616.176978    1288 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-02-24 05:40:16.184839: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# Starting Evaluation...
#
# ========================================================================================================================
# UNIFIED GLADIATOR LEADERBOARD
# ========================================================================================================================
#           Agent Stock  Net Profit ($)  ROI (%)  CAGR (%)  Trades  Fees ($)  vs B&H ROI (%)  vs SP500 ROI (%)
# dqn_trading_bot  AAPL          470.28     4.70      0.75      90      10.0         -264.32           -107.42
# dqn_trading_bot   AMD        -3255.62   -32.56     -6.22      90      10.0         -344.39           -144.68
# dqn_trading_bot  INTC        -1716.90   -17.17     -3.02      90      10.0           -0.37           -129.29
# dqn_trading_bot  MSFT          883.33     8.83      1.39      90      10.0         -155.52           -103.29
# dqn_trading_bot  NVDA         2419.35    24.19      3.60      90      10.0        -3106.51            -87.93
# ppo_trading_bot  AAPL          188.72     1.89      0.31      90      10.0         -267.14           -110.24
# ppo_trading_bot   AMD         -397.06    -3.97     -0.66      90      10.0         -315.80           -116.09
# ppo_trading_bot  INTC          238.96     2.39      0.39      90      10.0           19.18           -109.73
# ppo_trading_bot  MSFT        -1016.51   -10.17     -1.73      90      10.0         -174.52           -122.29
# ppo_trading_bot  NVDA        -2044.83   -20.45     -3.66      90      10.0        -3151.15           -132.57
# ========================================================================================================================
